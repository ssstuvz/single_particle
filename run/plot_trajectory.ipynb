# %%
px=fromfile('px.dat', dtype='float64')
py=fromfile('py.dat', dtype='float64')
pz=fromfile('pz.dat', dtype='float64')
x=fromfile('x.dat', dtype='float64')
y=fromfile('y.dat', dtype='float64')
z=fromfile('z.dat', dtype='float64')

# %%
plot(px)

# %%
gamma=sqrt(1+px*px+pz*pz)
plot(1/sqrt(gamma))

# %% [markdown]
# plot(px,py)

# %%
plot(pz)

# %%
plot(x)
#xlim(0, 10000)
#ylim(-1,1)

# %%
plot(z)

# %%
t=linspace(0, 8000, 80000)
plot( 0.01*(t), (z)/(2*pi)  )

#flipud()
#xlim(0, 10)
xlim(0, 25)
xlabel('z, wavelengths')
ylabel('t, periods')
#savefig('single_particle_intgate_t-z.png', dpi=300)

datacomp = loadtxt('x-t.dat')
plot(datacomp[0, :]-20/(2*pi), datacomp[1, :], 'r')

# %%
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14)
plot(x/(2*pi), z/(2*pi))


xlabel('transverse y', fontsize=20)
ylabel('longitudinal x', fontsize=20)
savefig('single_particle.svg', dpi=300)

# %%
plot(x, y)

# %%
plot(y, z)
